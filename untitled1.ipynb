# %% [markdown]
# <a href="https://colab.research.google.com/github/LHHoang1101/traffic-sign-detection/blob/main/untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#check gpu
# !nvidia-smi
# Out:
# Wed Apr 30 20:04:27 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8              9W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
#mount gg drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import files
uploaded = files.upload()  # Chọn file .zip chứa dataset
# Out:
#      <input type="file" id="files-00080c0f-2efa-4b63-a73b-2fd6c32733e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-00080c0f-2efa-4b63-a73b-2fd6c32733e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install numpy==1.23.5 --force-reinstall

# %%
#tải thư viện ultralytics

# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.7/112.6 GB disk)

# %%
#import thư viện yolo từ ultralytics
from ultralytics import YOLO

from IPython.display import display, Image

# %%
#giải nén
import zipfile
import os

# Đường dẫn đến file zip và nơi giải nén
zip_path = '/content/drive/MyDrive/traffic-sign/nontrain/images3.zip'
extract_to = '/content/drive/MyDrive/traffic-sign/images'

# Tạo thư mục nếu chưa có
os.makedirs(extract_to, exist_ok=True)

# Giải nén
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_to)

print("✅ Giải nén thành công!")
# Out:
# ✅ Giải nén thành công!

# %%
#đếm số lượng ảnh trong folder images
import os

# Đường dẫn đến folder chứa ảnh (thay đổi cho đúng với folder của bạn)
folder_path = '/content/drive/MyDrive/traffic-sign/images/images'

# Các định dạng ảnh muốn đếm
image_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.gif', '.webp')

# Đếm số file ảnh
count = sum([1 for file in os.listdir(folder_path) if file.lower().endswith(image_extensions)])
print(f"Số lượng ảnh trong folder: {count}")
# Out:
# Số lượng ảnh trong folder: 5285

# %%
HOME = "/content/drive/MyDrive/HOME"

# %%
#tạo file datasets
# !mkdir -p {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="NaVdCOAVZSY52ofbRf6k")
project = rf.workspace("hh-aqt7y").project("traffic-sign-viet-nam-hcm-y0hnj")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# /content/drive/MyDrive/HOME/datasets
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# %cd {HOME}

# !yolo task=detect mode=train model="/content/drive/MyDrive/HOME/runs/detect/train/weights/best.pt" data='/content/drive/MyDrive/HOME/datasets/data.yaml' epochs=100 imgsz=640
# Out:
# /content/drive/MyDrive/HOME
# New https://pypi.org/project/ultralytics/8.3.120 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# YOLOv8n (Nano) có khoảng 6.7 triệu tham số.
#
# YOLOv8s (Small) có khoảng 11 triệu tham số.
#
# YOLOv8m (Medium) có khoảng 25 triệu tham số.
#
# YOLOv8l (Large) có khoảng 45 triệu tham số.
#
# YOLOv8x (Extra Large) có khoảng 70 triệu tham số.

# %%
#kiểm tra model đã sử dụng
from ultralytics import YOLO

# Tải mô hình
model = YOLO("/content/drive/MyDrive/HOME/runs/detect/train7/weights/best.pt")  # Hoặc "yolov8m.pt", "yolov8x.pt"

# In thông tin mô hình
# Out:
# Model summary: 365 layers, 68,169,942 parameters, 0 gradients, 258.2 GFLOPs
# (365, 68169942, 0, 258.2139392)

# %%
pip install numpy==1.23.5 --force-reinstall
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 41.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jaxlib 0.5.1 requires numpy>=1.25, but you have numpy 1.23.5 which is incompatible.
# treescope 0.1.9 requires numpy>=1.25.2, but you have numpy 1.23.5 which is incompatible.
# chex 0.1.89 requires numpy>=1.24.1, but you have numpy 1.23.5 which is incompatible.
# bigframes 2.1.0 requires numpy>=1.24.0, but you have numpy 1.23.5 which is incompatible.
# pymc 5.22.0 requires numpy>=1.25.0, but you have numpy 1.23.5 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.23.5 which is incompatible.
# ...

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/HOME/runs/detect/train/results.csv')

# Loại bỏ khoảng trắng đầu/cuối cột để tránh lỗi
df.columns = df.columns.str.strip()

# Tìm epoch có mAP50-95 cao nhất
best_epoch = df['metrics/mAP50-95(B)'].idxmax()
print(f'Best.pt là ở epoch: {best_epoch}')
# Out:
# Best.pt là ở epoch: 77

# %%
# !yolo val model='/content/drive/MyDrive/HOME/runs/detect/train/weights/best.pt' data='/content/drive/MyDrive/HOME/datasets/data.yaml'
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 268 layers, 68,140,902 parameters, 0 gradients, 257.5 GFLOPs
# val: Scanning /content/drive/MyDrive/HOME/datasets/valid/labels.cache... 58 images, 11 backgrounds, 0 corrupt: 100% 58/58 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 4/4 [00:04<00:00,  1.16s/it]
#                    all         58         61      0.906      0.798      0.894      0.791
#     Cam di nguoc chieu          7          8      0.876      0.888      0.967      0.814
#    Cam do xe ngay chan          3          6      0.966          1      0.995      0.805
#      Cam do xe ngay le          2          2      0.922          1      0.995      0.995
#      Cam dung va do xe          5          5      0.972          1      0.995      0.845
#               Cam moto          1          4          1      0.775      0.995      0.894
# ...

# %%
# %cd {HOME}
Image(filename=f'/content/drive/MyDrive/HOME/runs/detect/train/results.png', width=600)
# Out:
# /content/drive/MyDrive/HOME

# %%
# %cd {HOME}
Image(filename=f'/content/drive/MyDrive/HOME/runs/detect/train/confusion_matrix_normalized.png', width=600)
# Out:
# /content/drive/MyDrive/HOME

# %%
# %cd {HOME}
Image(filename=f'/content/drive/MyDrive/HOME/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# /content/drive/MyDrive/HOME

# %%
# %cd {HOME}
Image(filename=f'/content/drive/MyDrive/HOME/runs/detect/train7/confusion_matrix_normalized.png', width=600)
# Out:
# /content/drive/MyDrive/HOME

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model='/content/drive/MyDrive/HOME/runs/detect/train7/weights/best.pt' conf=0.25 source='/content/drive/MyDrive/HOME/runs/4.jpg' save=true
# Out:
# /content/drive/MyDrive/HOME
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 268 layers, 68,140,902 parameters, 0 gradients, 257.5 GFLOPs
#
# image 1/1 /content/drive/MyDrive/HOME/runs/4.jpg: 384x640 1 Cam dung va do xe, 72.2ms
# Speed: 2.5ms preprocess, 72.2ms inference, 154.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict14
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename='/content/drive/MyDrive/HOME/runs/detect/predict3/loi-di-nguoc-chieu.jpg', height=600)
# Out:
# /content/drive/MyDrive/HOME
